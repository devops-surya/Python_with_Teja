# %%
a = 1 
b = 2 
# * Note : In ipynb file in each cell last value wiil be printed by default . We can also print(a + b)
print(a + b)
a + b
# Out:
# 3
# 3

# %%
a = 2 * 2 
a
# Out:
# 2

# %%
a = 10
b = 5

# %%
a / b
# Out:
# 2.0

# %%
a * b
# Out:
# 50

# %%
a // b
# Out:
# 2

# %%
a % b
# Out:
# 0

# %%
a = 4 
a = a ** 2
a
# Out:
# 16

# %%
a = 5 
a += 1 # a = a +1 
a
# Out:
# 6

# %%
a = 5 
a *= 2 # a= a * 2
a
# Out:
# 10

# %%
a = 5 
a **= 2 # a = a ** 2 
a
# Out:
# 25

# %%
a = 10 
b = 5 
a > b
# Out:
# True

# %%
a = 10 
b = 5
a < b
# Out:
# False

# %%
a = 5 
1 < a < 10
# Out:
# True

# %%
a = 5 
1 < a < 4
# Out:
# False

# %%
# calculate simple intrest
principal = 100000
interest_rate = 24
time_in_years = 5

simple_interest = principal * interest_rate * time_in_years / 100
print(simple_interest)

total_amount = principal + simple_interest
print(total_amount)
# Out:
# 120000.0
# 220000.0

# %%
principal = 100000
annual_interest = 0.24
number_of_times_interest_compunded_per_year = 1
time_in_years = 5 

final_amount = principal * ( 1 +  (annual_interest / number_of_times_interest_compunded_per_year) ) ** (number_of_times_interest_compunded_per_year * 5)
final_amount
compound_interest = final_amount - principal
compound_interest
# Out:
# 193162.50623999996
