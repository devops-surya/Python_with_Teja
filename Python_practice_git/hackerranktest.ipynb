# %%
def is_leap(year) -> bool:
    leap = False
    
    # Write your logic here
   #  while 1900 <= year <= 10**5:
    if year % 4 == 0 and year % 400 ==0:
        leap =True
    elif year % 100 == 0:
        leap = False
    return leap

# %%
is_leap(1992)
# Out:
# False
